# %% [markdown]
# Question 1 <br/> To perform a matrix multiplication between a matrix A of dimensions $𝑛 × 𝑘$ and a matrix B of dimensions $k × m$, you need to calculate each element of the resulting matrix 𝐶 of dimensions $𝑛 × 𝑚$.
# <br/>
# Each element $C_{ij}$ in the resulting matrix C is computed as:<br/>
# $C_{ij}=\sum_{r=1}^{k}{A_{ir}.B_{rj}}$
# For each element $C_{ij}$: <br/>
# We need to perform k multiplications of $A_{ir}.B_{rj}$ and k-1 additions to add these products.
# <br/>
# Since there are $m × n$ elements, total no. of multiplications are $m × n × k$ and total number of additions are $m × n × (k-1)$

# %%
# Question 2
import numpy as np
import math
import time
def matrix_multiply_list(A, B):
    n = len(A)
    k = len(A[0])
    m = len(B[0])
    result = np.zeros((n, m))
    
    for i in range(n):
        for j in range(m):
            for l in range(k):
                result[i][j] += A[i][l] * B[l][j]
    return result
# Function to multiply two matrices using NumPy's dot function
def matrix_multiply_numpy(A, B):
    return np.dot(A, B)

# %%
#Define matrix m1,m2
m1=np.random.randint(50, size=(4,6))
m2=np.random.randint(50, size=(6,10))

# %%
# Timing the manual multiplication
start = time.time()
result_list = matrix_multiply_list(m1, m2)
end = time.time()
time_list = end - start
# Timing the NumPy multiplication
start = time.time()
result_np = matrix_multiply_numpy(m1, m2)
end = time.time()
time_np = end - start
print("List Multiply time",time_list,"\nNumpy multiply time",time_np)
if time_list>time_np:
    print("List Matrix Multiplication is faster")
else:
    print("Numpy matrix multiplication is faster")
# Out:
# List Multiply time 0.0003113746643066406
# Numpy multiply time 0.0
# List Matrix Multiplication is faster

# %% [markdown]
# NumPy performs operations on entire arrays simultaneously, reducing overhead compared to looping through elements in Python lists and so its faster.

# %%
#Question 3
# Manual Bubble Sort to sort the array
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]
    return arr
def median_bubble_sort(arr):
    sorted_arr = bubble_sort(arr)
    n = len(sorted_arr)
    if n % 2 == 0:
        return (sorted_arr[n // 2 - 1] + sorted_arr[n // 2]) / 2
    else:
        return sorted_arr[n // 2]
# time complexity is O(n^2)

# %%
#A better method is mergesort
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]
        
        merge_sort(left_half)
        merge_sort(right_half)
        
        i = j = k = 0
        
        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1
        
        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1
        
        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr
def median_merge_sort(arr):
    sorted_arr = merge_sort(arr)
    n = len(sorted_arr)
    if n % 2 == 0:
        return (sorted_arr[n // 2 - 1] + sorted_arr[n // 2]) / 2
    else:
        return sorted_arr[n // 2]
#time complexity here is O(nlogn)

# %%
arr = np.random.randint(0, 100, size=1000)

# %%
# Timing the Bubble Sort method
start = time.time()
median_bubble_sort_result = median_bubble_sort(arr)
end = time.time()
time_bubble_sort = end - start

# Timing the Merge Sort method
start = time.time()
median_merge_sort_result = median_merge_sort(arr)
end = time.time()
time_merge_sort = end - start

# Timing NumPy's median function
start = time.time()
median_numpy = np.median(arr)
end = time.time()
time_numpy = end - start

print(f"Time taken by Bubble Sort method: {time_bubble_sort} seconds")
print(f"Time taken by Merge Sort method: {time_merge_sort} seconds")
print(f"Time taken by NumPy median function: {time_numpy} seconds")

print(f"Median by Bubble Sort: {median_bubble_sort_result}")
print(f"Median by Merge Sort: {median_merge_sort_result}")
print(f"Median by NumPy: {median_numpy}")
# Out:
# Time taken by Bubble Sort method: 0.11382460594177246 seconds
# Time taken by Merge Sort method: 0.015633344650268555 seconds
# Time taken by NumPy median function: 0.0 seconds
# Median by Bubble Sort: 49.0
# Median by Merge Sort: 49.0
# Median by NumPy: 49.0

# %%
if time_bubble_sort < time_merge_sort and time_bubble_sort < time_numpy:
    print("Bubble sort is fastest")
elif time_merge_sort < time_bubble_sort and time_merge_sort < time_numpy:
    print("Merge sort is fastest")
elif time_numpy < time_bubble_sort and time_numpy<time_merge_sort:
    print("Numpy is fastest")
# Out:
# Numpy is fastest

# %% [markdown]
# Question 4 <br/>The gradient is found out by the formula <br/> $\nabla f=\left(\frac{\partial f}{\partial x},\frac{\partial f}{\partial y}\right)$ <br/> Now $\frac{\partial f}{\partial x}$ = $2xy+y^3\cos{x}$ and $\frac{\partial f}{\partial y}$= $x^2+3y^2\sin{x}$ <br/> Therefore, gradient is $(2xy+y^3\cos{x},x^2+3y^2\sin{x})$

# %%
#Question 5
# !pip install jax jaxlib
from jax import grad
import jax.numpy as jnp
def f(x, y):
    return x**2 * y + y**3 * jnp.sin(x)
df_dx = grad(f,argnums=0)
df_dy = grad(f,argnums=1)
# Random values for x and y
x_val = np.random.uniform(-10, 10)
y_val = np.random.uniform(-10, 10)

#Compute the gradient normally
grad_normal= (2*x_val*y_val+math.pow(y_val,3)*math.cos(x_val),x_val*x_val+3*y_val*y_val*math.sin(x_val))
df_dx_r= df_dx(x_val,y_val)
df_dy_r= df_dy(x_val,y_val)
print(f"Random values: x = {x_val}, y = {y_val}")
print(f"Gradient: ({df_dx_r},{df_dy_r})")
print(f"Gradient: {grad_normal}")
# Out:
# ...
# Random values: x = 3.467211105443173, y = -4.188139638521595
# Gradient: (40.55958557128906,-4.811798095703125)
# Gradient: (40.55958284957016, -4.811804508701098)

# %%
#Question 6
import sympy as sp
x, y = sp.symbols('x y')
f = x**2 * y + y**3 * sp.sin(x)

# Compute the gradient
grad_f_x = sp.diff(f, x)  # Partial derivative with respect to x
grad_f_y = sp.diff(f, y)  # Partial derivative with respect to y

print(f"Partial derivative with respect to x: {grad_f_x}")
print(f"Partial derivative with respect to y: {grad_f_y}")

grad_f_x_val = grad_f_x.subs({x: x_val, y: y_val})
grad_f_y_val = grad_f_y.subs({x: x_val, y: y_val})

print(f"Gradient: ({grad_f_x_val},{grad_f_y_val})")
# Out:
# Partial derivative with respect to x: 2*x*y + y**3*cos(x)
# Partial derivative with respect to y: x**2 + 3*y**2*sin(x)
# Gradient: (40.5595828495702,-4.81180450870109)

# %%
#Question 7
student_records={
    2022: {"Branch 1": {"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}},"Branch 2":{"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}}},
    2023: {"Branch 1": {"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}},"Branch 2":{"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}}},
    2024: {"Branch 1": {"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}},"Branch 2":{"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}}},
    2025: {"Branch 1": {"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}},"Branch 2":{"Roll Number":1,"Name":"N","Marks":{"Maths:":100,"English:":70}}},
}
import pprint
pprint.pprint(student_records)
# Out:
# {2022: {'Branch 1': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
#                      'Roll Number': 1},
#         'Branch 2': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
#                      'Roll Number': 1}},
#  2023: {'Branch 1': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
#                      'Roll Number': 1},
#         'Branch 2': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
#                      'Roll Number': 1}},
#  2024: {'Branch 1': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
#                      'Roll Number': 1},
#         'Branch 2': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
#                      'Roll Number': 1}},
#  2025: {'Branch 1': {'Marks': {'English:': 70, 'Maths:': 100},
#                      'Name': 'N',
# ...

# %%
#Question 8
class Database:
    class Year:
        def __init__(self, year):
            self.year = year
            self.branches = {}
        
        def add_branch(self, branch_name):
            self.branches[branch_name] = Database.Branch(branch_name)
        
        def __repr__(self):
            return f"Year(Year: {self.year}, Branches: {self.branches})"
    
    class Branch:
        def __init__(self, branch):
            self.branch = branch
            self.students = {}
        
        def add_student(self, rollno, name):
            self.students[rollno] = Database.Student(rollno, name)
        
        def __repr__(self):
            return f"Branch(Branch: {self.branch}, Students: {self.students})"
    
    class Student:
        def __init__(self, rollno, name):
            self.rollno = rollno
            self.name = name
            self.marks = {}
        
        def add_mark(self, subject, number):
            self.marks[subject] = Database.Marks(subject, number)
        
        def __repr__(self):
            return f"Student(Roll No: {self.rollno}, Name: {self.name}, Marks: {self.marks})"
    
    class Marks:
        def __init__(self, subject, number):
            self.subject = subject
            self.number = number
        
        def __repr__(self):
            return f"Marks(Subject: {self.subject}, Number: {self.number})"

    def __init__(self):
        self.years = {}

    def add_year(self, year):
        self.years[year.year] = year

    def __repr__(self):
        return f"Database(Years: {self.years})"

# %%
#Question 9
import matplotlib.pyplot as plt
x= np.arange(0.5,100,0.5)

# %%
y = x
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y = x*x
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x^2')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y = (x*x*x)/100
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = x^3/100')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = sin(x)')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y = (np.sin(x))/x
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = (sin(x))/x')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y = np.log(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = log(x)')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
y = np.exp(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y, color='blue')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y = e^x')
plt.legend()
plt.grid(True)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Question 10
import pandas as pd
matrix = np.random.uniform(1, 2, size=(20, 5))
df=pd.DataFrame(matrix)
df.columns=["a","b","c","d","e"]
print(matrix)
print(df)
# Find the column with the highest standard deviation
std_devs = df.std()
max_std_dev_column = std_devs.idxmax()  

# Find the row with the lowest mean
means = df.mean(axis=1)
min_mean_row_index = means.idxmin()

# Print results
print(f"Column with the highest standard deviation: {max_std_dev_column}")
print(f"Row with the lowest mean: {min_mean_row_index}")
# Out:
# [[1.05785569 1.9835012  1.82534656 1.78763445 1.6614127 ]
#  [1.1099263  1.14763353 1.69092785 1.09302433 1.23246558]
#  [1.10789001 1.77169151 1.34178544 1.4877477  1.28082103]
#  [1.09983904 1.35432417 1.70213808 1.52758938 1.68694103]
#  [1.77103212 1.72688006 1.79707312 1.04928954 1.64950408]
#  [1.63107633 1.36852684 1.41551938 1.42909846 1.58909919]
#  [1.45719954 1.48896197 1.28254628 1.45066333 1.41789744]
#  [1.20483522 1.12158097 1.30665103 1.95143819 1.98876149]
#  [1.62806961 1.08018028 1.27605744 1.22613429 1.48031836]
#  [1.94957313 1.30625578 1.80304356 1.78771189 1.21551348]
#  [1.47228149 1.12985769 1.76988892 1.71914908 1.8980901 ]
#  [1.16723909 1.3824145  1.98926875 1.25777971 1.38262766]
#  [1.85993074 1.91675784 1.66385248 1.69498662 1.47855005]
#  [1.54248036 1.15032942 1.89808599 1.91677744 1.74431674]
#  [1.61338887 1.82078372 1.99140705 1.00595114 1.85350432]
#  [1.29210165 1.65627204 1.57952833 1.88714451 1.33642313]
# ...

# %%
#Question 11
#Adding column f
df['f'] = df[['a', 'b', 'c', 'd', 'e']].sum(axis=1)
print(df.head())
# Out:
#           a         b         c         d         e         f    g
# 0  1.057856  1.983501  1.825347  1.787634  1.661413  8.315751  GT8
# 1  1.109926  1.147634  1.690928  1.093024  1.232466  6.273978  LT8
# 2  1.107890  1.771692  1.341785  1.487748  1.280821  6.989936  LT8
# 3  1.099839  1.354324  1.702138  1.527589  1.686941  7.370832  LT8
# 4  1.771032  1.726880  1.797073  1.049290  1.649504  7.993779  LT8

# %%
df['g'] = 'GT8'  # Default value
df.loc[df['f'] < 8, 'g'] = 'LT8' 
print(df.head())
# Out:
#           a         b         c         d         e         f    g
# 0  1.057856  1.983501  1.825347  1.787634  1.661413  8.315751  GT8
# 1  1.109926  1.147634  1.690928  1.093024  1.232466  6.273978  LT8
# 2  1.107890  1.771692  1.341785  1.487748  1.280821  6.989936  LT8
# 3  1.099839  1.354324  1.702138  1.527589  1.686941  7.370832  LT8
# 4  1.771032  1.726880  1.797073  1.049290  1.649504  7.993779  LT8

# %%
# Find the number of rows where column 'g' is 'LT8'
lt8_count = df['g'].value_counts().get('LT8', 0)
print(lt8_count)
# Out:
# 15

# %%
# Find the standard deviation of column 'f' for rows where 'g' is 'LT8'
std_dev_lt8 = df.loc[df['g'] == 'LT8', 'f'].std()

# Find the standard deviation of column 'f' for rows where 'g' is 'GT8'
std_dev_gt8 = df.loc[df['g'] == 'GT8', 'f'].std()
print(std_dev_lt8,std_dev_gt8)
# Out:
# 0.486276069496571 0.19865272630127956

# %%
#Question 12
#Broadcasting in NumPy allows operations between arrays of different shapes by automatically expanding the smaller array to match the dimensions of the larger array. This feature makes it easier to perform element-wise operations without explicit looping.
# 2D array
array_2d = np.array([[1, 2, 3],
                     [4, 5, 6]])
# 1D array
array_1d = np.array([10, 20, 30])
result_1d = array_2d + array_1d
print("\nResult after adding 1D array to 2D array (broadcasting 1D array across rows):")
print(result_1d)
# Out:
# Result after adding 1D array to 2D array (broadcasting 1D array across rows):
# [[11 22 33]
#  [14 25 36]]

# %%
#Question 13
def find_argmin(arr):
    min_index = 0 #index of min element
    for i in range(len(arr)):
        if arr[i] < arr[min_index]:
            min_index = i
    return min_index

# %%
arr = np.random.randint(20, size=20)
print(arr)
# Out:
# [13  5  4 18  1 18 10 19 10 11  1 14  2  0 18  2  3 18  9  5]

# %%
# Compute the index of the minimum element using customized function.
index_custom = find_argmin(arr)
print("Index of the minimum element (custom function):", index_custom)

# Compute the index of the minimum element using NumPy's argmin function for verification
index_np = np.argmin(arr)
print("Index of the minimum element (np.argmin):", index_np)
# Out:
# Index of the minimum element (custom function): 13
# Index of the minimum element (np.argmin): 13
